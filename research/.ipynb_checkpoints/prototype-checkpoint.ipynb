# %% [markdown]
# # TERA — Travel Expense Review Assistant
#
# ## Prototype Development
#
# This notebook is used for the initial development and evaluation of the AI components of TERA.
#
# TERA is a research prototype developed as part of a Bachelor's thesis at the University of Bayreuth. The goal of the project is to investigate how artificial intelligence can support the review of international travel expense reimbursements.
#
# The initial experiments focus on:
# - processing travel-related documents,
# - extracting structured information,
# - identifying inconsistencies or potentially relevant issues,
# - evaluating different AI-based approaches.
#
# The final reimbursement decision remains with the human reviewer.

# %% [markdown]
# ## Use Case 1 — Extract Structured Information from a Machine-Readable Hotel Invoice
#
# **Goal:**
# Extract relevant reimbursement-related information from a hotel invoice that contains machine-readable text.
#
# **Input:**
# A machine-readable PDF hotel invoice with an embedded text layer. No OCR is required.
#
# **Method:**
# Extract the text directly from the PDF and provide the extracted content to an AI model using a structured extraction prompt.
#
# **Expected output:**
# A structured representation containing relevant fields such as hotel name, invoice date, stay dates, currency, and total amount.
#
# **Evaluation:**
# Compare the AI-extracted values with manually identified ground-truth values from the source document.

# %%
import pymupdf
import json
import requests
from pydantic import BaseModel
from pathlib import Path

# %% [markdown]
# ### 1. Load and Inspect the Document

# %%
DATA_DIR = Path("data")
document_path = DATA_DIR / "hotel_invoice.pdf"

doc = pymupdf.open(document_path)

text = "\n".join(page.get_text() for page in doc)

print(text[:3000])
# Out:
# SYNTHETIC TEST INVOICE | Machine-readable PDF with selectable text
# Page 1
# NORTHSTAR HOTEL BERLIN
# Fictional property - synthetic test document
# Alexanderplatz 99
# 10178 Berlin, Germany
# +49 30 5550 0199
# billing@northstar-example.test
# INVOICE
# PAID
# INVOICE NUMBER
# NSB-2026-0914-1042
# INVOICE DATE
# 14 September 2026
# GUEST NAME
# Alex Morgan
# BOOKING REFERENCE
# TERA-DEMO-74291
# CHECK-IN
# 10 September 2026, 15:00
# CHECK-OUT
# 14 September 2026, 11:00
# STAY
# 4 room nights
# ROOM
# Deluxe King - 508
# CHARGES
# Description
# Qty
# Unit rate
# Net
# Tax
# Amount
# Accommodation - Deluxe King
# 4 nights
# EUR 140.00
# EUR 560.00
# VAT 7%
# EUR 599.20
# Breakfast
# 4
# EUR 15.00
# EUR 60.00
# VAT 19%
# EUR 71.40
# Berlin city tax (7.5% of room net)
# 1
# EUR 42.00
# EUR 42.00
# Exempt
# EUR 42.00
# Tax summary
# Taxable base
# Tax amount
# VAT 7% - accommodation
# EUR 560.00
# EUR 39.20
# VAT 19% - breakfast
# EUR 60.00
# EUR 11.40
# City tax - exempt from VAT
# EUR 42.00
# EUR 0.00
# Subtotal (net + city tax)
# EUR 662.00
# VAT total
# EUR 50.60
# TOTAL AMOUNT
# EUR 712.60
# Currency
# EUR
# PAYMENT METHOD
# Visa ending 4242
# PAYMENT STATUS
# Paid in full on 14 September 2026
# Note: This invoice is entirely fictional and was generated solely for TERA extraction testing. No real guest, hotel, booking,
# payment card, or transaction is represented.

# %% [markdown]
# ### 2. Define the Target Extraction Schema

# %% [markdown]
# Not final schema. This is a preliminary version and will be updated based on the results of the experiments.

# %%
class HotelInvoiceExtraction(BaseModel):
    hotel_name: str | None = None
    hotel_address: str | None = None
    invoice_number: str | None = None
    invoice_date: str | None = None
    guest_name: str | None = None
    check_in_date: str | None = None
    check_out_date: str | None = None
    number_of_nights: int | None = None
    currency: str | None = None
    room_rate: float | None = None
    city_tax: float | None = None
    total_amount: float | None = None
    payment_method: str | None = None

# %% [markdown]
# ### 3. Define Ground Truth

# %%
ground_truth = {
    "hotel_name": "NORTHSTAR HOTEL BERLIN",
    "hotel_address": "Alexanderplatz 99, 10178 Berlin, Germany",
    "invoice_number": "NSB-2026-0914-1042",
    "invoice_date": "2026-09-14",
    "guest_name": "Alex Morgan",
    "check_in_date": "2026-09-10",
    "check_out_date": "2026-09-14",
    "number_of_nights": 4,
    "currency": "EUR",
    "room_rate": 140.00,
    "city_tax": 42.00,
    "total_amount": 712.60,
    "payment_method": "Visa ending 4242"
}

# %% [markdown]
# ### 4. Define the Extraction Prompt

# %%
schema_json = json.dumps(
    HotelInvoiceExtraction.model_json_schema(),
    indent=2
)

prompt = f"""
You are extracting structured information from a hotel invoice.

Return only valid JSON that follows exactly this schema:

{schema_json}

Rules:
- Use only information explicitly present in the document.
- Do not infer missing values.
- Use null if a value is not available.
- Preserve monetary values as numbers.
- Use ISO date format YYYY-MM-DD where possible.
- Return JSON only.

Document:
{text}
"""

# %% [markdown]
# ### 5. Run AI Extraction

# %%
MODEL_NAME = "gemma3:12b"

def call_model(prompt: str) -> str:
    response = requests.post(
        "http://localhost:11434/api/generate",
        json={
            "model": MODEL_NAME,
            "prompt": prompt,
            "stream": False,
            "format": "json",
            "options": {
                "temperature": 0
            }
        },
        timeout=120,
    )

    response.raise_for_status()
    return response.json()["response"]

# %%
model_response = call_model(prompt)

print(model_response)
# Out:
# {
#   "hotel_name": "NORTHSTAR HOTEL BERLIN",
#   "hotel_address": "Alexanderplatz 99, 10178 Berlin, Germany",
#   "invoice_number": "NSB-2026-0914-1042",
#   "invoice_date": "2026-09-14",
#   "guest_name": "Alex Morgan",
#   "check_in_date": "2026-09-10",
#   "check_out_date": "2026-09-14",
#   "number_of_nights": 4,
#   "currency": "EUR",
#   "room_rate": null,
#   "city_tax": 42.00,
#   "total_amount": 712.60,
#   "payment_method": "Visa ending 4242"
# }

# %% [markdown]
# ### 6. Validate Structured Output

# %%
result = HotelInvoiceExtraction.model_validate_json(model_response)

result
# Out:
# HotelInvoiceExtraction(hotel_name='NORTHSTAR HOTEL BERLIN', hotel_address='Alexanderplatz 99, 10178 Berlin, Germany', invoice_number='NSB-2026-0914-1042', invoice_date='2026-09-14', guest_name='Alex Morgan', check_in_date='2026-09-10', check_out_date='2026-09-14', number_of_nights=4, currency='EUR', room_rate=None, city_tax=42.0, total_amount=712.6, payment_method='Visa ending 4242')

# %%
extracted_data = result.model_dump()

extracted_data
# Out:
# {'hotel_name': 'NORTHSTAR HOTEL BERLIN',
#  'hotel_address': 'Alexanderplatz 99, 10178 Berlin, Germany',
#  'invoice_number': 'NSB-2026-0914-1042',
#  'invoice_date': '2026-09-14',
#  'guest_name': 'Alex Morgan',
#  'check_in_date': '2026-09-10',
#  'check_out_date': '2026-09-14',
#  'number_of_nights': 4,
#  'currency': 'EUR',
#  'room_rate': None,
#  'city_tax': 42.0,
#  'total_amount': 712.6,
#  'payment_method': 'Visa ending 4242'}

# %% [markdown]
# ### 7. Compare with Ground Truth

# %%
comparison = {}

for field, expected_value in ground_truth.items():
    actual_value = extracted_data.get(field)

    comparison[field] = {
        "expected": expected_value,
        "actual": actual_value,
        "match": expected_value == actual_value,
    }

comparison
# Out:
# {'hotel_name': {'expected': 'NORTHSTAR HOTEL BERLIN',
#   'actual': 'NORTHSTAR HOTEL BERLIN',
#   'match': True},
#  'hotel_address': {'expected': 'Alexanderplatz 99, 10178 Berlin, Germany',
#   'actual': 'Alexanderplatz 99, 10178 Berlin, Germany',
#   'match': True},
#  'invoice_number': {'expected': 'NSB-2026-0914-1042',
#   'actual': 'NSB-2026-0914-1042',
#   'match': True},
#  'invoice_date': {'expected': '2026-09-14',
#   'actual': '2026-09-14',
#   'match': True},
#  'guest_name': {'expected': 'Alex Morgan',
#   'actual': 'Alex Morgan',
#   'match': True},
#  'check_in_date': {'expected': '2026-09-10',
#   'actual': '2026-09-10',
#   'match': True},
#  'check_out_date': {'expected': '2026-09-14',
#   'actual': '2026-09-14',
#   'match': True},
#  'number_of_nights': {'expected': 4, 'actual': 4, 'match': True},
#  'currency': {'expected': 'EUR', 'actual': 'EUR', 'match': True},
#  'room_rate': {'expected': 140.0, 'actual': None, 'match': False},
#  'city_tax': {'expected': 42.0, 'actual': 42.0, 'match': True},
#  'total_amount': {'expected': 712.6, 'actual': 712.6, 'match': True},
#  'payment_method': {'expected': 'Visa ending 4242',
#   'actual': 'Visa ending 4242',
#   'match': True}}

# %%
matches = sum(
    1 for item in comparison.values()
    if item["match"]
)

total = len(comparison)

accuracy = matches / total

print(f"Correct fields: {matches}/{total}")
print(f"Field-level accuracy: {accuracy:.2%}")
# Out:
# Correct fields: 12/13
# Field-level accuracy: 92.31%

# %%
errors = {
    field: values
    for field, values in comparison.items()
    if not values["match"]
}

errors
# Out:
# {'room_rate': {'expected': 140.0, 'actual': None, 'match': False}}
